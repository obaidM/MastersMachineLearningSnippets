# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## simple distribution plot 

sns.distplot(tips['total_bill'],kde=False,bins=20)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.pairplot(tips,hue='smoker')

# %% [markdown]
# # Categorical plottig with sns. We prefer barplot

# %%
sns.barplot(x='time',y='total_bill',data=tips)

# %%
sns.barplot(x='day',y='total_bill',data=tips)

# %%
sns.countplot(x='day',data=tips)

# %%
### box plots are amazing as they show alot of info in one go 

sns.boxplot(x='day',y='total_bill',data=tips,hue='time')

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
# Out:
# C:\Users\obaid\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
